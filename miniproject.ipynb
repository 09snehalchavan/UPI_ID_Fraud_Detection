# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('fraud.csv')

data.head()
# Out:
#   Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 0             T1     4174             1292.76   ATM Withdrawal
# 1             T2     4507             1554.58   ATM Withdrawal
# 2             T3     1860             2395.02   ATM Withdrawal
# 3             T4     2294              100.10     Bill Payment
# 4             T5     2130             1490.50      POS Payment
#
#    Time_of_Transaction Device_Used       Location  \
# 0                 16.0      Tablet  San Francisco
# 1                 13.0      Mobile       New York
# 2                  NaN      Mobile            NaN
# 3                 15.0     Desktop        Chicago
# 4                 19.0      Mobile  San Francisco
#
#    Previous_Fraudulent_Transactions  Account_Age  \
# 0                                 0          119
# 1                                 4           79
# 2                                 3          115
# 3                                 4            3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51000 entries, 0 to 50999
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Transaction_ID                    51000 non-null  object
#  1   User_ID                           51000 non-null  int64
#  2   Transaction_Amount                48480 non-null  float64
#  3   Transaction_Type                  51000 non-null  object
#  4   Time_of_Transaction               48448 non-null  float64
#  5   Device_Used                       48527 non-null  object
#  6   Location                          48453 non-null  object
#  7   Previous_Fraudulent_Transactions  51000 non-null  int64
#  8   Account_Age                       51000 non-null  int64
#  9   Number_of_Transactions_Last_24H   51000 non-null  int64
#  10  Payment_Method                    48531 non-null  object
# ...

# %%
data.describe()
# Out:
#             User_ID  Transaction_Amount  Time_of_Transaction  \
# count  51000.000000        48480.000000         48448.000000
# mean    3005.110176         2996.249784            11.488400
# std     1153.121107         5043.932555             6.922954
# min     1000.000000            5.030000             0.000000
# 25%     2007.000000         1270.552500             5.000000
# 50%     2996.000000         2524.100000            12.000000
# 75%     4006.000000         3787.240000            17.000000
# max     4999.000000        49997.800000            23.000000
#
#        Previous_Fraudulent_Transactions   Account_Age  \
# count                      51000.000000  51000.000000
# mean                           1.995725     60.033902
# std                            1.415150     34.384131
# min                            0.000000      1.000000
# 25%                            1.000000     30.000000
# 50%                            2.000000     60.000000
# ...

# %%
obj = (data.dtypes == 'object')
object_cols = list(obj[obj].index)
print("Categorical variables:", len(object_cols))

int_ = (data.dtypes == 'int')
num_cols = list(int_[int_].index)
print("Integer variables:", len(num_cols))

fl = (data.dtypes == 'float')
fl_cols = list(fl[fl].index)
print("Float variables:", len(fl_cols))
# Out:
# Categorical variables: 5
# Integer variables: 0
# Float variables: 2

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='Transaction_Amount', data=data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sns.countplot(x='Transaction_Amount', data=data)
#
# NameError: name 'data' is not defined

# %%
sns.barplot(x='Transaction_Amount', y='Fraudulent', data=data)

# %%
data['Fraudulent'].value_counts()

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(data.apply(lambda x: pd.factorize(x)[0]).corr(),
			cmap='BrBG',
			fmt='.2f',
			linewidths=2,
			annot=True)
# Out:
# <Axes: >

# %%
type_new = pd.get_dummies(data['BankName'], drop_first=True)
data_new = pd.concat([data, type_new], axis=1)
data_new.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BankName'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 type_new = pd.get_dummies(data['BankName'], drop_first=True)
# ...

# %%
X = data_new.drop(['TransactionID', 'Amount','MerchantCategory','TransactionType', 'AvgTransactionAmount', 'UnusualLocation', 'UnusualAmount','Payment Status', 'FraudFlag', 'PhoneNumber', 'BankName'], axis=1)
y = data_new['FraudFlag']

X.shape, y.shape
# Out:
# ((10000, 5), (10000,))

# %%
//As the prediction ia a classification problem so the model we will be use.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score as ras
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
models = [LogisticRegression(), XGBClassifier(),
          RandomForestClassifier(n_estimators=7,
                                 criterion='entropy', 
                                 random_state=7)]

for i in range(len(models)):
    models[i].fit(X_train, y_train)
    print(f'{models[i]} : ')
    
    train_preds = models[i].predict_proba(X_train)[:, 1]
    print('Training Accuracy : ', ras(y_train, train_preds))
    
    y_preds = models[i].predict_proba(X_test)[:, 1]
    print('Validation Accuracy : ', ras(y_test, y_preds))
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 models = [LogisticRegression(), XGBClassifier(),
#       2           RandomForestClassifier(n_estimators=7,
#       3                                  criterion='entropy',
#       4                                  random_state=7)]
#       6 for i in range(len(models)):
#       7     models[i].fit(X_train, y_train)
#
# NameError: name 'LogisticRegression' is not defined

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = ConfusionMatrixDisplay.from_estimator(models[1], X_test, y_test) 

cm.plot(cmap='Blues') 

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 4
#       1 from sklearn.metrics import ConfusionMatrixDisplay
#       2 import matplotlib.pyplot as plt
# ----> 4 cm = ConfusionMatrixDisplay.from_estimator(models[1], X_test, y_test)
#       6 cm.plot(cmap='Blues')
#       8 plt.show()
#
# File /lib/python3.12/site-packages/sklearn/metrics/_plot/confusion_matrix.py:320, in ConfusionMatrixDisplay.from_estimator(cls, estimator, X, y, labels, sample_weight, normalize, display_labels, include_values, xticks_rotation, values_format, cmap, ax, colorbar, im_kw, text_kw)
#     318 if not is_classifier(estimator):
#     319     raise ValueError(f"{method_name} only supports classifiers")
# --> 320 y_pred = estimator.predict(X)
#     322 return cls.from_predictions(
#     323     y,
#     324     y_pred,
#    (...)
#     336     text_kw=text_kw,
#     337 )
#
# ...
