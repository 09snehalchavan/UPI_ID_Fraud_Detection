# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('fraud.csv')

data.head()
# Out:
#    TransactionID   Amount MerchantCategory TransactionType  \
# 0   842835309389  8589.00      Electronics             P2M
# 1   592863054785  9090.54      Electronics             P2M
# 2   373481869464  8814.41      Electronics             P2P
# 3   285572156436  3971.25      Restaurants             P2P
# 4   874207772966  4376.74        Groceries             P2M
#
#    AvgTransactionAmount  UnusualLocation  UnusualAmount  Payment Status  \
# 0                670.31            False           True           False
# 1               7265.96            False           True           False
# 2               8750.89             True          False            True
# 3               8348.14             True           True           False
# 4               1719.74             True           True           False
#
#    FraudFlag   PhoneNumber    BankName
# 0       True    2798604680         BOB
# 1      False    3614149152  ICICI Bank
# 2      False  912661191911  ICICI Bank
# 3      False  916358088125         SBI
# 4      False    5132838721  ICICI Bank

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TransactionID         10000 non-null  int64
#  1   Amount                10000 non-null  float64
#  2   MerchantCategory      10000 non-null  object
#  3   TransactionType       10000 non-null  object
#  4   AvgTransactionAmount  10000 non-null  float64
#  5   UnusualLocation       10000 non-null  bool
#  6   UnusualAmount         10000 non-null  bool
#  7   Payment Status        10000 non-null  bool
#  8   FraudFlag             10000 non-null  bool
#  9   PhoneNumber           10000 non-null  int64
#  10  BankName              10000 non-null  object
# dtypes: bool(4), float64(2), int64(2), object(3)
# memory usage: 468.8+ KB

# %%
data.describe()
# Out:
#        TransactionID        Amount  AvgTransactionAmount   PhoneNumber
# count   1.000000e+04  10000.000000          10000.000000  1.000000e+04
# mean    5.515428e+11   5004.460629           4988.532019  3.085201e+11
# std     2.595428e+11   2881.189782           2887.007255  4.290684e+11
# min     1.000276e+11      2.200000              1.550000  1.593770e+05
# 25%     3.269720e+11   2526.945000           2497.180000  3.809523e+09
# 50%     5.527816e+11   4951.010000           4947.515000  7.582981e+09
# 75%     7.787159e+11   7528.650000           7487.210000  9.124914e+11
# max     9.997475e+11   9999.120000           9998.970000  9.199982e+11

# %%
obj = (data.dtypes == 'object')
object_cols = list(obj[obj].index)
print("Categorical variables:", len(object_cols))

int_ = (data.dtypes == 'int')
num_cols = list(int_[int_].index)
print("Integer variables:", len(num_cols))

fl = (data.dtypes == 'float')
fl_cols = list(fl[fl].index)
print("Float variables:", len(fl_cols))
# Out:
# Categorical variables: 3
# Integer variables: 0
# Float variables: 2

# %%
# %pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='BankName', data=data)
# Out:
# <Axes: xlabel='BankName', ylabel='count'>

# %%
sns.barplot(x='BankName', y='FraudFlag', data=data)
# Out:
# <Axes: xlabel='BankName', ylabel='FraudFlag'>

# %%
data['FraudFlag'].value_counts()
# Out:
# FraudFlag
# False    9035
# True      965
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(data.apply(lambda x: pd.factorize(x)[0]).corr(),
			cmap='BrBG',
			fmt='.2f',
			linewidths=2,
			annot=True)
# Out:
# <Axes: >

# %%
type_new = pd.get_dummies(data['BankName'], drop_first=True)
data_new = pd.concat([data, type_new], axis=1)
data_new.head()
# Out:
#    TransactionID   Amount MerchantCategory TransactionType  \
# 0   842835309389  8589.00      Electronics             P2M
# 1   592863054785  9090.54      Electronics             P2M
# 2   373481869464  8814.41      Electronics             P2P
# 3   285572156436  3971.25      Restaurants             P2P
# 4   874207772966  4376.74        Groceries             P2M
#
#    AvgTransactionAmount  UnusualLocation  UnusualAmount  Payment Status  \
# 0                670.31            False           True           False
# 1               7265.96            False           True           False
# 2               8750.89             True          False            True
# 3               8348.14             True           True           False
# 4               1719.74             True           True           False
#
#    FraudFlag   PhoneNumber    BankName    BOB  HDFC Bank  ICICI Bank    KMB  \
# 0       True    2798604680         BOB   True      False       False  False
# 1      False    3614149152  ICICI Bank  False      False        True  False
# 2      False  912661191911  ICICI Bank  False      False        True  False
# 3      False  916358088125         SBI  False      False       False  False
# 4      False    5132838721  ICICI Bank  False      False        True  False
#
#      SBI
# 0  False
# 1  False
# 2  False
# 3   True
# 4  False

# %%
X = data_new.drop(['TransactionID', 'Amount','MerchantCategory','TransactionType', 'AvgTransactionAmount', 'UnusualLocation', 'UnusualAmount','Payment Status', 'FraudFlag', 'PhoneNumber', 'BankName'], axis=1)
y = data_new['FraudFlag']

X.shape, y.shape
# Out:
# ((10000, 5), (10000,))

# %%
//As the prediction ia a classification problem so the model we will be use.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score as ras
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
models = [LogisticRegression(), XGBClassifier(),
          RandomForestClassifier(n_estimators=7,
                                 criterion='entropy', 
                                 random_state=7)]

for i in range(len(models)):
    models[i].fit(X_train, y_train)
    print(f'{models[i]} : ')
    
    train_preds = models[i].predict_proba(X_train)[:, 1]
    print('Training Accuracy : ', ras(y_train, train_preds))
    
    y_preds = models[i].predict_proba(X_test)[:, 1]
    print('Validation Accuracy : ', ras(y_test, y_preds))
    print()
# Out:
# LogisticRegression() :
# Training Accuracy :  0.516274734354083
# Validation Accuracy :  0.5289180562753032
#
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) :
# Training Accuracy :  0.516274734354083
# Validation Accuracy :  0.5289180562753032
#
# RandomForestClassifier(criterion='entropy', n_estimators=7, random_state=7) :
# Training Accuracy :  0.5159117768422175
# Validation Accuracy :  0.5225775757971145

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = ConfusionMatrixDisplay.from_estimator(models[1], X_test, y_test) 

cm.plot(cmap='Blues') 

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 4
#       1 from sklearn.metrics import ConfusionMatrixDisplay
#       2 import matplotlib.pyplot as plt
# ----> 4 cm = ConfusionMatrixDisplay.from_estimator(models[1], X_test, y_test)
#       6 cm.plot(cmap='Blues')
#       8 plt.show()
#
# File /lib/python3.12/site-packages/sklearn/metrics/_plot/confusion_matrix.py:320, in ConfusionMatrixDisplay.from_estimator(cls, estimator, X, y, labels, sample_weight, normalize, display_labels, include_values, xticks_rotation, values_format, cmap, ax, colorbar, im_kw, text_kw)
#     318 if not is_classifier(estimator):
#     319     raise ValueError(f"{method_name} only supports classifiers")
# --> 320 y_pred = estimator.predict(X)
#     322 return cls.from_predictions(
#     323     y,
#     324     y_pred,
#    (...)
#     336     text_kw=text_kw,
#     337 )
#
# File /lib/python3.12/site-packages/xgboost/sklearn.py:1565, in XGBClassifier.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1556 def predict(
#    1557     self,
#    1558     X: ArrayLike,
#    (...)
#    1562     iteration_range: Optional[IterationRange] = None,
#    1563 ) -> ArrayLike:
#    1564     with config_context(verbosity=self.verbosity):
# -> 1565         class_probs = super().predict(
#    1566             X=X,
#    1567             output_margin=output_margin,
#    1568             validate_features=validate_features,
#    1569             base_margin=base_margin,
#    1570             iteration_range=iteration_range,
#    1571         )
#    1572         if output_margin:
#    1573             # If output_margin is active, simply return the scores
#    1574             return class_probs
#
# File /lib/python3.12/site-packages/xgboost/sklearn.py:1186, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1184 if self._can_use_inplace_predict():
#    1185     try:
# -> 1186         predts = self.get_booster().inplace_predict(
#    1187             data=X,
#    1188             iteration_range=iteration_range,
#    1189             predict_type="margin" if output_margin else "value",
#    1190             missing=self.missing,
#    1191             base_margin=base_margin,
#    1192             validate_features=validate_features,
#    1193         )
#    1194         if _is_cupy_alike(predts):
#    1195             import cupy  # pylint: disable=import-error
#
# File /lib/python3.12/site-packages/xgboost/core.py:2510, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2508     data, fns, _ = _transform_pandas_df(data, enable_categorical)
#    2509     if validate_features:
# -> 2510         self._validate_features(fns)
#    2511 if _is_list(data) or _is_tuple(data):
#    2512     data = np.array(data)
#
# File /lib/python3.12/site-packages/xgboost/core.py:3075, in Booster._validate_features(self, feature_names)
#    3069 if my_missing:
#    3070     msg += (
#    3071         "\ntraining data did not have the following fields: "
#    3072         + ", ".join(str(s) for s in my_missing)
#    3073     )
# -> 3075 raise ValueError(msg.format(self.feature_names, feature_names))
#
# ValueError: feature_names mismatch: ['Bank of Baroda', 'HDFC Bank', 'ICICI Bank', 'Kotak Mahindra Bank', 'State Bank of India'] ['BOB', 'HDFC Bank', 'ICICI Bank', 'KMB', 'SBI']
# expected State Bank of India, Bank of Baroda, Kotak Mahindra Bank in input data
# training data did not have the following fields: KMB, BOB, SBI
